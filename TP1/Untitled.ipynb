# %%
import pandas as pd

_df = pd.read_csv('jfkrelease-2017-dce65d0ec70a54d5744de17d280f3ad2.csv', sep = ";", parse_dates = ['Doc Date'])
_df[:4]
# Out:
#             File Name       Record Num NARA Release Date Formerly Withheld  \
# 0  DOCID-32105709.pdf  178-10004-10309        26/10/2017           In Part
# 1  DOCID-32105710.pdf  178-10004-10308        26/10/2017           In Part
# 2  DOCID-32105711.pdf  178-10004-10307        26/10/2017           In Part
# 3  DOCID-32105718.pdf  178-10004-10300        26/10/2017           In Part
#
#       Agency    Doc Date    Doc Type       File Num To Name         From Name  \
# 0  KISS/SCOW  06/05/1975       NOTES      JUNE 1975     NaN  SCOWCROFT, BRENT
# 1  KISS/SCOW  04/12/1975       NOTES     APRIL 1975     NaN  SCOWCROFT, BRENT
# 2  KISS/SCOW  03/05/1975       NOTES   JANUARY 1975     NaN  SCOWCROFT, BRENT
# 3  KISS/SCOW  06/26/1975  MEMORANDUM  JUNE 26, 1975     NaN               NaN
#
#                         Title  Num Pages Originator  \
# 0               P/K 5 JUNE 75        3.0         WH
# 1               P/K 12 APR 75        2.0         WH
# ...
